# %%
#Imort
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read dataset
df=pd.read_csv("hotel booking.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month
# 0  Resort Hotel            0        342               2015               July  \
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month
# 0                        27                          1  \
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type
# 0                        0                     0       2  ...      Transient  \
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month
# 0  Resort Hotel            0        342               2015               July  \
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month
# 0                        27                          1  \
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type
# 0                        0                     0       2  ...      Transient  \
# ...

# %%
df.shape
# Out:
# (119390, 36)

# %%
df["reservation_status"].unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year
# count  119390.000000  119390.000000      119390.000000  \
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month
# count             119390.000000              119390.000000  \
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment
# count       119390             119390  119390  118902         119390  \
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type
# count                119390             119390             119390  \
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390  \
# unique            3             4                  3                     926
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
for col in df.describe(include="object").columns:
    print(col)
    print(df[col].unique())
    print("-"*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df["reservation_status_date"]=pd.to_datetime(df["reservation_status_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                 is_canceled  lead_time  arrival_date_year
# is_canceled                        1.000000   0.293123           0.016660  \
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# stays_in_week_nights               0.024765   0.165799           0.030883
# adults                             0.060017   0.119519           0.029635
# children                           0.005048  -0.037622           0.054624
# babies                            -0.032491  -0.020915          -0.013192
# is_repeated_guest                 -0.084793  -0.124410           0.010341
# previous_cancellations             0.110133   0.086042          -0.119822
# ...

# %%
plt.figure(figsize=(12,7))
corrM=df.corr(numeric_only=True)
sns.heatmap(corrM,annot=True)
plt.show()

# %% [markdown]
# # Visualization of relation and decission

# %%
df["hotel"].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %% [markdown]
# ### Which hotel have more customer

# %%
sns.countplot(x="hotel",data=df).set_title("Reservation status in different hotel")
# Out:
# Text(0.5, 1.0, 'Reservation status in different hotel')

# %% [markdown]
# ### Which hotel have more reservation status

# %%
sns.countplot(x="hotel",hue="reservation_status",data=df).set_title("Reservation status")
# Out:
# Text(0.5, 1.0, 'Reservation status')

# %% [markdown]
# ### which hotel have more reservation cancelation.

# %%
sns.countplot(x="hotel",hue="is_canceled",data=df).set_title("Reservation canceled")
# Out:
# Text(0.5, 1.0, 'Reservation canceled')

# %%
people_canceled=df[df["is_canceled"]==1]
sns.countplot(x="hotel",data=people_canceled)
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
people_not_canceled_reservation=df[df["is_canceled"]==0]
sns.countplot(x="hotel",data=people_not_canceled_reservation)
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %% [markdown]
# ### top 10 country which canceled resavation inn

# %%
top_10_country=people_canceled["country"].value_counts()[:10]
plt.figure(figsize=(10,5))
plt.title("Top 10 country reservation canceled")
plt.pie(top_10_country,autopct="%.2f",labels=top_10_country.index)
plt.show()

# %% [markdown]
# # top 10 counrty  reservation not canceled

# %%
top_10_country_raservation=people_not_canceled_reservation["country"].value_counts()[:10]
plt.figure(figsize=(10,5))
plt.title("Top 10 country reservation nott canceled")
plt.pie(top_10_country_raservation,autopct="%.2f",labels=top_10_country_raservation.index)
plt.show()

# %%
df["country"].value_counts()
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
country_name=df["country"].value_counts()[:10]
plt.title("Which counry is more benifit for business")
plt.pie(country_name,labels=country_name.index)
plt.show()

# %% [markdown]
# ### why they canceled more reservation.

# %%
df["month"]=df["reservation_status_date"].dt.month
plt.figure(figsize=(8,3))
sns.countplot(x="month",hue="is_canceled",data=df,palette="winter").set_title("Reservation status per month")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.barplot(x="month",y="adr",data=df[df["is_canceled"]==1].groupby("month")[["adr"]].sum().reset_index()).set_title("Adr per month")
plt.show()

# %% [markdown]
# ### which month reservation are  more canceled

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="arrival_date_month",hue="is_canceled",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df["arrival_date_year"].unique()
# Out:
# array([2015, 2016, 2017], dtype=int64)

# %% [markdown]
# ### Which year reservation are more

# %%
df["arrival_date_year"].value_counts()
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
sns.countplot(x="arrival_date_year",data=df)
# Out:
# <Axes: xlabel='arrival_date_year', ylabel='count'>

# %% [markdown]
# ### which type of room are so demandable

# %%
df["reserved_room_type"].value_counts()
# Out:
# reserved_room_type
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64

# %%
sns.displot(x="reserved_room_type",hue="hotel",data=df)

# %% [markdown]
# ## why A type room are so demand in both hotel.

# %%
sns.barplot(x="reserved_room_type",y="adr",data=df)
# Out:
# <Axes: xlabel='reserved_room_type', ylabel='adr'>

# %% [markdown]
# #### which meal is populer in both hotel

# %%
df["meal"].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
sns.histplot(x="meal",hue="hotel",data=df).set_title("Meal in both hotel")
# Out:
# Text(0.5, 1.0, 'Meal in both hotel')

# %%
df["customer_type"].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %% [markdown]
# ### which type of customer are more in both hotel

# %%
plt.figure(figsize=(10,3))
sns.countplot(x="customer_type",hue="hotel",data=df)
plt.show()

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year
# 0       Resort Hotel            0        342               2015  \
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number
# 0                    July                        27  \
# 1                    July                        27
# ...

# %%
new_df=df.drop(["arrival_date_month","reservation_status_date","email","phone-number","credit_card","name"],axis=1)
new_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year
# 0       Resort Hotel            0        342               2015  \
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#         arrival_date_week_number  arrival_date_day_of_month
# 0                             27                          1  \
# 1                             27                          1
# ...

# %%
new_df.to_csv("Feature data")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
new_df=new_df.apply(le.fit_transform)

# %%
new_df
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year
# 0           1            0        342                  0  \
# 1           1            0        478                  0
# 2           1            0          7                  0
# 3           1            0         13                  0
# 4           1            0         14                  0
# ...       ...          ...        ...                ...
# 119385      0            0         23                  2
# 119386      0            0        102                  2
# 119387      0            0         34                  2
# 119388      0            0        109                  2
# 119389      0            0        205                  2
#
#         arrival_date_week_number  arrival_date_day_of_month
# 0                             26                          0  \
# 1                             26                          0
# 2                             26                          0
# ...

# %%
new_df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
x=new_df.drop("reservation_status",axis=1)
y=new_df["reservation_status"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier= DecisionTreeClassifier(criterion='entropy', random_state=0) 
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.98722673590753

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators = 200, random_state = 0)
rf_model.fit(x_train, y_train) 
y_pred = rf_model.predict(x_test)
